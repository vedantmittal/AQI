# %%
import import_ipynb

# %%
from KNN import KNN
from LassoRegression import LassoRegression
from DecisionTreeRegressor import DecisionTreeRegressor
from RandomForestRegressor import RandomForestRegressor
from ANN import ANN
# Out:
# importing Jupyter notebook from KNN.ipynb
# importing Jupyter notebook from LassoRegression.ipynb
# importing Jupyter notebook from DecisionTreeRegressor.ipynb
# importing Jupyter notebook from RandomForestRegressor.ipynb
# importing Jupyter notebook from ANN.ipynb

# %%
from LinearRegression import LinearRegression
# Out:
# importing Jupyter notebook from LinearRegression.ipynb

# %%
data= {}

# %%
def LinearRegression1():
    val = LinearRegression()
    data['LinearRegression'] = val

# %%
def kNN2():
    val = KNN()
    data['KNN'] = val;

# %%
def LassoRegression3():
    val = LassoRegression()
    data['LassoRegression'] = val

# %%
def DecisionTreeRegressor4():
    val = DecisionTreeRegressor()
    data['DecisionTreeRegressor'] = val

# %%
def RandomForestRegressor5():
    val = RandomForestRegressor()
    data['RandomForestRegressor'] = val

# %%
def ANN6():
    val = ANN()
    data['ANN'] = val

# %%
LinearRegression1()

# %%
kNN2()

# %%
LassoRegression3()
# Out:
# C:\Users\Pradeep Sharma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1444197.3511959247, tolerance: 614.5592033746461
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Pradeep Sharma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1568739.7813254024, tolerance: 678.9710639134809
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Pradeep Sharma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1456481.2227170018, tolerance: 626.8737580831347
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
DecisionTreeRegressor4()
# Out:
# Fitting 10 folds for each of 10240 candidates, totalling 102400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 1048 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 3608 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 11800 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=-1)]: Done 17432 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 24088 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 31768 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 40472 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 50200 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 60952 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 69600 tasks      | elapsed:  5.4min
# ...

# %%
RandomForestRegressor5()
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.3s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# ...

# %%
ANN6()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 128)               1152
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# ...
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ...

# %%
data
# Out:
# {'LinearRegression': 60.725143317512384,
#  'KNN': 57.295545295538254,
#  'LassoRegression': 60.2313119485411,
#  'DecisionTreeRegressor': 48.71443533802212,
#  'RandomForestRegressor': 40.71809019704873,
#  'ANN': 62.43728881389585}

# %%
sorted(data.items(), key = lambda kv:(kv[1], kv[0]))
# Out:
# [('RandomForestRegressor', 40.71809019704873),
#  ('DecisionTreeRegressor', 48.71443533802212),
#  ('KNN', 57.295545295538254),
#  ('LassoRegression', 60.2313119485411),
#  ('LinearRegression', 60.725143317512384),
#  ('ANN', 62.43728881389585)]
